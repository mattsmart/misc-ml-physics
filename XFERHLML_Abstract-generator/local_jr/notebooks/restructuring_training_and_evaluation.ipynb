# %%
IN_COLAB = 'google.colab' in str(get_ipython())

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    # %cd /content/drive/MyDrive/Github/Abstract-generator/bumbleBERT/notebooks
    
    # %%capture
    # !pip install feedparser tokenizers transformers;

# %%
import os, torch, time, math, sys, re, csv
import numpy as np

sys.path.append('..' + os.sep )
from src import default
import src.data.dataset_class as dsc
import src.data.dataloader_class as dlc

from src.model.transformer_hf import TransformerModel
from src.model.generate_text import gen_some_text
from src.model.train_evaluate import train, evaluate
#from src.model.transformer import make_gpt_model # imports don't work

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Parameters

# %%
# ARCHITECTURE
maxLen     = 40 # maximum sentence length
vocabSize  = None # None if you want to let tokenizer do its thing
emsize     = 512 # embedding dimension
nhid       = 2048 # the dimension of the feedforward network model in torch.nn.TransformerEncoder
nlayers    = 12 # the number of torch.nn.TransformerEncoderLayer in torch.nn.TransformerEncoder
nhead      = 8 # the number of heads in the multiheadattention models
dropout    = 0.2 # the dropout value
batchSize = 10 #32
valBatchSize = 10 #32, not used right now.
epochs     = 50  # The number of epochs

TRAIN = True

# %% [markdown]
# ### Format Dataset
#
# Uses a custom dataset class, which is an iterable and callable structure that returns a sample from our dataset. Within this custom dataset, can determine all preprocessing.

# %%
# create dataset
dataset = dsc.ArxivDataset()
dataset = dsc.WikiTextDataset()

#train tokenizer (or use one already trained)
tknzrType = 'BPE'
tknzrTrain = True
tknzrFast = True

_ = dataset.tokenizer(tknzrTrain, tknzrType, tknzrFast=tknzrFast)
# Out:
# Warning : overwriting previously save tokenizer with                        same filename ( /home/jrothschild/Projects/Abstract-generator/bumbleBERT/data/tokenizers/BPE_wikitext-2-raw_.json ).

# %% [markdown]
# ### Creating DataLoaders
#
# Training is done on batches, so we need a way to extract groupings of the data in the appropriate format for our transformer model.
# Note that for transformers which we are training, dataloaders outputs both src (x[:-1] and tgt ([1:]).
# The collation of batches for different transformer models we have vary. For HuggingFace it's ( maxLen x batch_size ) whereas I think that the Annotated Transformer has ( batch_size x maxLen ).
#
# I created a custom Dataloader class that wraps splitting the dataset and also outputs different dataloaders for each.
#
# NOTE : Do not use the tokenizer before the training if you use num_workers>0!
# FastTokenizer does not play nicely with forking if you use it before the forking of your data:
# https://stackoverflow.com/questions/62691279/how-to-disable-tokenizers-parallelism-true-false-warning

# %%
dataloader = dlc.CustomDataloader(dataset, batchSize, maxLen)

# %% [markdown]
# ### Selecting model
#
# Here we choose which model we shall use for training. For now, I've selected the black box Transformer from HuggingFace because the collate_fn I've written gives the correct input size force it... however this can easily be changed!

# %%
# transformer from huggingface
# TODO : Change to the Annotated Transformer if I want
model = TransformerModel(dataset.vocabSize, emsize, nhead, nhid, nlayers, dropout).to(device)

# criterion
criterion = torch.nn.CrossEntropyLoss()#ignore_index=tknzr.get_vocab()["<pad>"])

# optimizer
paramsAdam  = [{'params' : model.parameters(), 'lr' : 1e-3, 'betas' : (0.9, 0.999), 'eps' : 1e-08, 'weight_decay' : 0.0}]
paramsAdamW = [{'params' : model.parameters(), 'lr' : 5e-5, 'betas' : (0.9, 0.999), 'eps' : 1e-08, 'weight_decay' : 0.0}]
paramsSGD   = [{'params' : model.parameters(), 'lr' : 0.5, 'momentum' : 0.0, 'dampening' : 0.0, 'weight_decay' : 0.0}]

#optimizer = torch.optim.SGD( paramsSGD )
#optimizer = torch.optim.Adam( paramsAdam )
optimizer = torch.optim.AdamW( paramsAdamW )

# scheduler
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95) # 1.0 to signify no decay rate

# %% [markdown]
# ### Training
#
# Training loop!

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"  # fasttokenizer should not be used before forking. Something
                                                # to figure out. What this does is suppress some warning messages 
                                                # https://stackoverflow.com/questions/62691279/how-to-disable-tokenizers-parallelism-true-false-warning
                                                # doesn't seem to affect the timing though
if TRAIN:
    best_val_loss = float("inf")
    best_model = None
    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        train( model, dataloader.train, device, dataset.vocabSize, epoch, optimizer, scheduler, criterion, maxLen)
        val_loss = evaluate(model, dataloader.valid, device, dataset.vocabSize, criterion, maxLen, len(dataloader.dsetValid))
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
              'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                         val_loss, math.exp(val_loss)))
                                         # Why is math.exp so large????
        print('-' * 89)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model

        scheduler.step()

    # save best model (two methods)
    modelFull = default.MODEL_DIR + os.sep + f'{dataset.name}_epoch{epochs}.pth'
    modelWeights = default.MODEL_DIR + os.sep + f'{dataset.name}_weights_epoch{epochs}.pth'
    modelFullBest = default.MODEL_DIR + os.sep + f'{dataset.name}_epoch{epochs}_best.pth'
    modelWeightsBest = default.MODEL_DIR + os.sep + f'{dataset.name}_weights_epoch{epochs}_best.pth'
    # approach 1: save model (class) entirely (uses pickle)
    torch.save(model, modelFull)
    torch.save(best_model, modelFullBest)
    # approach 2: save model weights
    torch.save(best_model.state_dict(), modelWeightsBest)
# Out:
# | epoch   1 |   200/  486 batches | lr 0.00 | ms/batch 29.17 | loss  7.73 | ppl  2275.87
# | epoch   1 |   400/  486 batches | lr 0.00 | ms/batch 28.87 | loss  6.88 | ppl   974.42
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 14.72s | valid loss 25.60 | valid ppl 131361991014.71
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/  486 batches | lr 0.00 | ms/batch 29.09 | loss  6.50 | ppl   663.50
# | epoch   2 |   400/  486 batches | lr 0.00 | ms/batch 28.25 | loss  6.39 | ppl   596.02
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 14.51s | valid loss 24.91 | valid ppl 66039371377.62
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/  486 batches | lr 0.00 | ms/batch 28.98 | loss  6.23 | ppl   507.75
# | epoch   3 |   400/  486 batches | lr 0.00 | ms/batch 28.66 | loss  6.18 | ppl   484.25
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 14.65s | valid loss 24.40 | valid ppl 39456027973.33
# -----------------------------------------------------------------------------------------
# | epoch   4 |   200/  486 batches | lr 0.00 | ms/batch 29.87 | loss  6.04 | ppl   420.84
# | epoch   4 |   400/  486 batches | lr 0.00 | ms/batch 29.44 | loss  6.00 | ppl   404.25
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 15.00s | valid loss 24.04 | valid ppl 27570473214.06
# -----------------------------------------------------------------------------------------
# | epoch   5 |   200/  486 batches | lr 0.00 | ms/batch 30.01 | loss  5.88 | ppl   359.01
# | epoch   5 |   400/  486 batches | lr 0.00 | ms/batch 28.84 | loss  5.81 | ppl   333.12
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 14.76s | valid loss 23.83 | valid ppl 22286250223.92
# -----------------------------------------------------------------------------------------
# | epoch   6 |   200/  486 batches | lr 0.00 | ms/batch 29.31 | loss  5.70 | ppl   300.21
# | epoch   6 |   400/  486 batches | lr 0.00 | ms/batch 28.95 | loss  5.69 | ppl   295.31
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 14.77s | valid loss 23.60 | valid ppl 17734687710.83
# -----------------------------------------------------------------------------------------
# | epoch   7 |   200/  486 batches | lr 0.00 | ms/batch 29.30 | loss  5.58 | ppl   264.86
# | epoch   7 |   400/  486 batches | lr 0.00 | ms/batch 28.62 | loss  5.54 | ppl   254.19
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 14.57s | valid loss 23.52 | valid ppl 16363252948.47
# -----------------------------------------------------------------------------------------
# | epoch   8 |   200/  486 batches | lr 0.00 | ms/batch 30.14 | loss  5.43 | ppl   227.56
# | epoch   8 |   400/  486 batches | lr 0.00 | ms/batch 29.99 | loss  5.45 | ppl   232.65
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 15.11s | valid loss 23.40 | valid ppl 14554543121.75
# -----------------------------------------------------------------------------------------
# | epoch   9 |   200/  486 batches | lr 0.00 | ms/batch 29.20 | loss  5.33 | ppl   205.77
# | epoch   9 |   400/  486 batches | lr 0.00 | ms/batch 28.32 | loss  5.32 | ppl   204.76
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 14.54s | valid loss 23.32 | valid ppl 13471324989.20
# -----------------------------------------------------------------------------------------
# | epoch  10 |   200/  486 batches | lr 0.00 | ms/batch 29.11 | loss  5.21 | ppl   183.08
# | epoch  10 |   400/  486 batches | lr 0.00 | ms/batch 28.55 | loss  5.20 | ppl   182.04
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 14.59s | valid loss 23.23 | valid ppl 12232783179.35
# -----------------------------------------------------------------------------------------
# | epoch  11 |   200/  486 batches | lr 0.00 | ms/batch 29.06 | loss  5.11 | ppl   165.94
# | epoch  11 |   400/  486 batches | lr 0.00 | ms/batch 28.25 | loss  5.10 | ppl   164.74
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 14.44s | valid loss 23.20 | valid ppl 11875167622.73
# -----------------------------------------------------------------------------------------
# | epoch  12 |   200/  486 batches | lr 0.00 | ms/batch 28.91 | loss  5.04 | ppl   153.72
# | epoch  12 |   400/  486 batches | lr 0.00 | ms/batch 28.51 | loss  5.00 | ppl   148.98
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 14.58s | valid loss 23.20 | valid ppl 11897628053.58
# -----------------------------------------------------------------------------------------
# | epoch  13 |   200/  486 batches | lr 0.00 | ms/batch 29.31 | loss  4.95 | ppl   141.54
# | epoch  13 |   400/  486 batches | lr 0.00 | ms/batch 28.96 | loss  4.90 | ppl   134.38
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 14.76s | valid loss 23.16 | valid ppl 11408605342.52
# -----------------------------------------------------------------------------------------
# | epoch  14 |   200/  486 batches | lr 0.00 | ms/batch 29.18 | loss  4.85 | ppl   127.25
# | epoch  14 |   400/  486 batches | lr 0.00 | ms/batch 28.66 | loss  4.82 | ppl   124.15
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 14.76s | valid loss 23.19 | valid ppl 11816752911.75
# -----------------------------------------------------------------------------------------
# | epoch  15 |   200/  486 batches | lr 0.00 | ms/batch 28.63 | loss  4.76 | ppl   116.48
# | epoch  15 |   400/  486 batches | lr 0.00 | ms/batch 29.15 | loss  4.77 | ppl   118.10
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 14.68s | valid loss 23.14 | valid ppl 11197557213.84
# -----------------------------------------------------------------------------------------
# | epoch  16 |   200/  486 batches | lr 0.00 | ms/batch 29.22 | loss  4.69 | ppl   108.94
# | epoch  16 |   400/  486 batches | lr 0.00 | ms/batch 28.65 | loss  4.68 | ppl   107.98
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 14.63s | valid loss 23.15 | valid ppl 11328723291.58
# -----------------------------------------------------------------------------------------
# | epoch  17 |   200/  486 batches | lr 0.00 | ms/batch 29.43 | loss  4.61 | ppl   100.16
# | epoch  17 |   400/  486 batches | lr 0.00 | ms/batch 28.66 | loss  4.60 | ppl    99.31
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 14.74s | valid loss 23.15 | valid ppl 11291704358.14
# -----------------------------------------------------------------------------------------
# | epoch  18 |   200/  486 batches | lr 0.00 | ms/batch 29.32 | loss  4.54 | ppl    93.68
# | epoch  18 |   400/  486 batches | lr 0.00 | ms/batch 28.96 | loss  4.56 | ppl    95.46
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 14.66s | valid loss 23.21 | valid ppl 11984347026.25
# -----------------------------------------------------------------------------------------
# | epoch  19 |   200/  486 batches | lr 0.00 | ms/batch 29.26 | loss  4.50 | ppl    90.29
# | epoch  19 |   400/  486 batches | lr 0.00 | ms/batch 29.09 | loss  4.48 | ppl    87.92
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 14.76s | valid loss 23.24 | valid ppl 12377580589.73
# -----------------------------------------------------------------------------------------
# | epoch  20 |   200/  486 batches | lr 0.00 | ms/batch 29.81 | loss  4.42 | ppl    82.72
# | epoch  20 |   400/  486 batches | lr 0.00 | ms/batch 29.14 | loss  4.42 | ppl    83.14
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 14.87s | valid loss 23.24 | valid ppl 12367966010.66
# -----------------------------------------------------------------------------------------
# | epoch  21 |   200/  486 batches | lr 0.00 | ms/batch 28.84 | loss  4.37 | ppl    78.66
# | epoch  21 |   400/  486 batches | lr 0.00 | ms/batch 28.45 | loss  4.36 | ppl    77.95
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 14.47s | valid loss 23.24 | valid ppl 12328640751.53
# -----------------------------------------------------------------------------------------
# | epoch  22 |   200/  486 batches | lr 0.00 | ms/batch 30.06 | loss  4.32 | ppl    75.03
# | epoch  22 |   400/  486 batches | lr 0.00 | ms/batch 29.24 | loss  4.31 | ppl    74.20
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 14.94s | valid loss 23.28 | valid ppl 12934271583.66
# -----------------------------------------------------------------------------------------
# | epoch  23 |   200/  486 batches | lr 0.00 | ms/batch 29.40 | loss  4.27 | ppl    71.25
# | epoch  23 |   400/  486 batches | lr 0.00 | ms/batch 28.80 | loss  4.25 | ppl    69.97
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 14.77s | valid loss 23.30 | valid ppl 13146053011.94
# -----------------------------------------------------------------------------------------
# | epoch  24 |   200/  486 batches | lr 0.00 | ms/batch 29.96 | loss  4.21 | ppl    67.61
# | epoch  24 |   400/  486 batches | lr 0.00 | ms/batch 28.80 | loss  4.19 | ppl    66.18
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 14.87s | valid loss 23.32 | valid ppl 13482788941.54
# -----------------------------------------------------------------------------------------
# | epoch  25 |   200/  486 batches | lr 0.00 | ms/batch 29.36 | loss  4.19 | ppl    65.72
# | epoch  25 |   400/  486 batches | lr 0.00 | ms/batch 28.35 | loss  4.14 | ppl    62.67
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 14.61s | valid loss 23.29 | valid ppl 13037562204.96
# -----------------------------------------------------------------------------------------
# | epoch  26 |   200/  486 batches | lr 0.00 | ms/batch 30.16 | loss  4.13 | ppl    62.10
# | epoch  26 |   400/  486 batches | lr 0.00 | ms/batch 29.13 | loss  4.11 | ppl    60.90
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 14.86s | valid loss 23.34 | valid ppl 13728488628.37
# -----------------------------------------------------------------------------------------
# | epoch  27 |   200/  486 batches | lr 0.00 | ms/batch 28.76 | loss  4.06 | ppl    57.96
# | epoch  27 |   400/  486 batches | lr 0.00 | ms/batch 28.61 | loss  4.09 | ppl    59.70
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 14.50s | valid loss 23.41 | valid ppl 14707906659.16
# -----------------------------------------------------------------------------------------
# | epoch  28 |   200/  486 batches | lr 0.00 | ms/batch 29.46 | loss  4.03 | ppl    56.22
# | epoch  28 |   400/  486 batches | lr 0.00 | ms/batch 28.50 | loss  4.02 | ppl    55.96
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 14.65s | valid loss 23.36 | valid ppl 13932915998.77
# -----------------------------------------------------------------------------------------
# | epoch  29 |   200/  486 batches | lr 0.00 | ms/batch 29.83 | loss  3.99 | ppl    53.96
# | epoch  29 |   400/  486 batches | lr 0.00 | ms/batch 30.15 | loss  3.99 | ppl    54.10
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 15.11s | valid loss 23.44 | valid ppl 15180163868.58
# -----------------------------------------------------------------------------------------
# | epoch  30 |   200/  486 batches | lr 0.00 | ms/batch 29.69 | loss  3.95 | ppl    51.91
# | epoch  30 |   400/  486 batches | lr 0.00 | ms/batch 28.70 | loss  3.96 | ppl    52.64
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 14.80s | valid loss 23.44 | valid ppl 15085922209.46
# -----------------------------------------------------------------------------------------
# | epoch  31 |   200/  486 batches | lr 0.00 | ms/batch 29.06 | loss  3.94 | ppl    51.44
# | epoch  31 |   400/  486 batches | lr 0.00 | ms/batch 28.96 | loss  3.92 | ppl    50.44
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 14.72s | valid loss 23.41 | valid ppl 14662747197.80
# -----------------------------------------------------------------------------------------
# | epoch  32 |   200/  486 batches | lr 0.00 | ms/batch 29.38 | loss  3.89 | ppl    48.71
# | epoch  32 |   400/  486 batches | lr 0.00 | ms/batch 28.79 | loss  3.90 | ppl    49.21
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 14.79s | valid loss 23.44 | valid ppl 15193059810.32
# -----------------------------------------------------------------------------------------
# | epoch  33 |   200/  486 batches | lr 0.00 | ms/batch 30.14 | loss  3.87 | ppl    47.85
# | epoch  33 |   400/  486 batches | lr 0.00 | ms/batch 28.57 | loss  3.85 | ppl    47.13
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 14.80s | valid loss 23.52 | valid ppl 16349028955.41
# -----------------------------------------------------------------------------------------
# | epoch  34 |   200/  486 batches | lr 0.00 | ms/batch 29.60 | loss  3.83 | ppl    46.09
# | epoch  34 |   400/  486 batches | lr 0.00 | ms/batch 30.13 | loss  3.83 | ppl    45.89
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 15.09s | valid loss 23.46 | valid ppl 15456235630.63
# -----------------------------------------------------------------------------------------
# | epoch  35 |   200/  486 batches | lr 0.00 | ms/batch 29.47 | loss  3.80 | ppl    44.74
# | epoch  35 |   400/  486 batches | lr 0.00 | ms/batch 29.14 | loss  3.79 | ppl    44.11
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 14.81s | valid loss 23.50 | valid ppl 16013925358.20
# -----------------------------------------------------------------------------------------
# | epoch  36 |   200/  486 batches | lr 0.00 | ms/batch 29.95 | loss  3.80 | ppl    44.56
# | epoch  36 |   400/  486 batches | lr 0.00 | ms/batch 29.47 | loss  3.76 | ppl    43.02
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 14.98s | valid loss 23.53 | valid ppl 16532325324.40
# -----------------------------------------------------------------------------------------
# | epoch  37 |   200/  486 batches | lr 0.00 | ms/batch 29.90 | loss  3.75 | ppl    42.47
# | epoch  37 |   400/  486 batches | lr 0.00 | ms/batch 29.86 | loss  3.75 | ppl    42.38
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 15.01s | valid loss 23.56 | valid ppl 17055969653.22
# -----------------------------------------------------------------------------------------
# | epoch  38 |   200/  486 batches | lr 0.00 | ms/batch 29.83 | loss  3.71 | ppl    40.93
# | epoch  38 |   400/  486 batches | lr 0.00 | ms/batch 28.80 | loss  3.73 | ppl    41.56
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 14.80s | valid loss 23.56 | valid ppl 17124399122.20
# -----------------------------------------------------------------------------------------
# | epoch  39 |   200/  486 batches | lr 0.00 | ms/batch 29.78 | loss  3.69 | ppl    40.04
# | epoch  39 |   400/  486 batches | lr 0.00 | ms/batch 29.35 | loss  3.71 | ppl    40.74
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 14.86s | valid loss 23.56 | valid ppl 17056109788.47
# -----------------------------------------------------------------------------------------
# | epoch  40 |   200/  486 batches | lr 0.00 | ms/batch 29.57 | loss  3.68 | ppl    39.84
# | epoch  40 |   400/  486 batches | lr 0.00 | ms/batch 29.23 | loss  3.68 | ppl    39.57
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 14.87s | valid loss 23.60 | valid ppl 17728510077.19
# -----------------------------------------------------------------------------------------
# | epoch  41 |   200/  486 batches | lr 0.00 | ms/batch 29.40 | loss  3.66 | ppl    38.94
# | epoch  41 |   400/  486 batches | lr 0.00 | ms/batch 28.70 | loss  3.65 | ppl    38.37
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 14.73s | valid loss 23.62 | valid ppl 18047661130.64
# -----------------------------------------------------------------------------------------
# | epoch  42 |   200/  486 batches | lr 0.00 | ms/batch 29.53 | loss  3.65 | ppl    38.47
# | epoch  42 |   400/  486 batches | lr 0.00 | ms/batch 29.17 | loss  3.63 | ppl    37.59
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 14.79s | valid loss 23.64 | valid ppl 18563584972.27
# -----------------------------------------------------------------------------------------
# | epoch  43 |   200/  486 batches | lr 0.00 | ms/batch 29.12 | loss  3.62 | ppl    37.36
# | epoch  43 |   400/  486 batches | lr 0.00 | ms/batch 28.68 | loss  3.63 | ppl    37.58
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 14.61s | valid loss 23.59 | valid ppl 17525863670.06
# -----------------------------------------------------------------------------------------
# | epoch  44 |   200/  486 batches | lr 0.00 | ms/batch 28.67 | loss  3.60 | ppl    36.55
# | epoch  44 |   400/  486 batches | lr 0.00 | ms/batch 29.85 | loss  3.62 | ppl    37.27
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 14.87s | valid loss 23.61 | valid ppl 17918247779.14
# -----------------------------------------------------------------------------------------
# | epoch  45 |   200/  486 batches | lr 0.00 | ms/batch 29.25 | loss  3.59 | ppl    36.14
# | epoch  45 |   400/  486 batches | lr 0.00 | ms/batch 28.64 | loss  3.61 | ppl    36.90
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 14.78s | valid loss 23.66 | valid ppl 18866376804.63
# -----------------------------------------------------------------------------------------
# | epoch  46 |   200/  486 batches | lr 0.00 | ms/batch 29.29 | loss  3.57 | ppl    35.56
# | epoch  46 |   400/  486 batches | lr 0.00 | ms/batch 28.25 | loss  3.55 | ppl    34.98
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 14.59s | valid loss 23.65 | valid ppl 18672693240.78
# -----------------------------------------------------------------------------------------
# | epoch  47 |   200/  486 batches | lr 0.00 | ms/batch 29.29 | loss  3.56 | ppl    35.05
# | epoch  47 |   400/  486 batches | lr 0.00 | ms/batch 29.70 | loss  3.55 | ppl    34.87
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 15.00s | valid loss 23.67 | valid ppl 18953354405.78
# -----------------------------------------------------------------------------------------
# | epoch  48 |   200/  486 batches | lr 0.00 | ms/batch 30.84 | loss  3.54 | ppl    34.43
# | epoch  48 |   400/  486 batches | lr 0.00 | ms/batch 29.09 | loss  3.53 | ppl    33.98
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 15.03s | valid loss 23.66 | valid ppl 18929949001.09
# -----------------------------------------------------------------------------------------
# | epoch  49 |   200/  486 batches | lr 0.00 | ms/batch 29.96 | loss  3.54 | ppl    34.43
# | epoch  49 |   400/  486 batches | lr 0.00 | ms/batch 28.92 | loss  3.52 | ppl    33.91
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 14.89s | valid loss 23.68 | valid ppl 19184066068.05
# -----------------------------------------------------------------------------------------
# | epoch  50 |   200/  486 batches | lr 0.00 | ms/batch 29.52 | loss  3.51 | ppl    33.38
# | epoch  50 |   400/  486 batches | lr 0.00 | ms/batch 29.17 | loss  3.51 | ppl    33.46
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 14.86s | valid loss 23.70 | valid ppl 19688397871.49
# -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Text Generation
#
# Here I've simply taken the code Matt uses to generate text.

# %%
if not TRAIN:
    customFilename = 'arxiv_10000'
    customEpochs = 10
    modelFull = default.MODEL_DIR + os.sep + f'{customFilename}_epoch{customEpochs}_best.pth'
    modelWeights = default.MODEL_DIR + os.sep + f'{customFilename}_weights_epoch{customEpochs}_best.pth'
    
    # approach 1: load model (class) entirely (uses pickle)
    modelFullLoad = torch.load(modelFull, map_location=device)

    # approach 2: load model weights, need to have some parameter or something 
    modelLoad = TransformerModel(vocabSize, emsize, nhead, nhid, nlayers, dropout).to(device)
    modelWeightsLoad = modelLoad.load_state_dict( torch.load(modelWeights) )

# %%
# inspect both models
#print('model_A info...\n', modelFullLoad)
#print('\nmodel_B info...\n', modelWeightsLoad)

#print('model_A == model_B:', modelFullLoad == modelWeightsLoad)
#model = modelFullLoad
# Text generation example

#model = modelLoad
prompt = 'The dog ran'
ngen = 100
decode_style = 'greedy' #greedy, sample_topp
model.to('cpu')
generated_text = gen_some_text(
    best_model, dataset.transform, 'cpu', maxLen, text_prompt=prompt, tokens_to_gen=ngen, vis=False,
    decode_style=decode_style)
print("Text prompt:\n", prompt)
print("Number of tokens to generate:", ngen)
print("Generated_text:\n", generated_text)

# TODO: alternative generation
# currently 'greedy method'
# see: https://huggingface.co/blog/how-to-generate
# Out:
# <s>  The  dog  ran
# tensor([-5.4660, -6.1401, -3.6607,  ..., -1.0406, -1.7796, -2.9135],
#        grad_fn=<SelectBackward0>)
# The dog ran  into
# <s>  The  dog  ran  into
# tensor([-6.5964, -9.0464, -3.9420,  ..., -0.4227, -0.9724, -2.2983],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a
# <s>  The  dog  ran  into  a
# tensor([-2.7266, -6.0550, -2.4167,  ..., -1.7753, -0.9441, -1.2870],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical
# <s>  The  dog  ran  into  a  tropical
# tensor([-1.9276, -4.3682,  0.6975,  ..., -0.2348,  0.2135, -2.1654],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression
# <s>  The  dog  ran  into  a  tropical  depression
# tensor([ -6.6767, -11.7690,   1.0595,  ...,  -2.4775,  -5.8395,  -1.9622],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on
# <s>  The  dog  ran  into  a  tropical  depression  on
# tensor([-3.6805, -9.0180,  2.2344,  ..., -3.1880, -0.6575, -3.7623],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August
# <s>  The  dog  ran  into  a  tropical  depression  on  August
# tensor([ -2.8731, -10.2710,   3.1833,  ...,  -3.6669,  -3.6687,  -3.5371],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19
# tensor([ -3.9311, -12.4024,   4.8638,  ...,  -3.4047,  -3.6055,  -4.1096],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,
# tensor([ -3.6299, -10.6734,   3.9353,  ...,  -4.0478,  -3.5578,  -3.6975],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and
# tensor([ -6.1284, -10.4623,   3.0777,  ...,  -3.9900,  -3.8487,  -5.7273],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the
# tensor([-0.6191, -7.3879,  1.4707,  ..., -3.5114, -2.5861, -3.1896],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA
# tensor([-3.8522, -4.6043,  3.4562,  ..., -0.0047, -2.4526, -3.2668],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded
# tensor([-6.0676, -9.1535,  2.1794,  ..., -1.5662, -2.4773, -2.9075],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the
# tensor([-0.4658, -7.2546,  1.0292,  ..., -3.6277, -2.6040, -1.8513],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm
# tensor([ -5.5913, -10.2261,   3.0779,  ...,  -2.5225,  -6.2965,  -1.6787],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to
# tensor([-1.6801, -5.9342,  3.7257,  ..., -1.7725, -2.9994, -2.6645],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical
# tensor([-0.5083, -3.4400,  2.3053,  ..., -1.2576, -0.4181, -1.8109],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones
# tensor([-4.2040, -8.6353,  2.0129,  ..., -2.1606, -5.1866, -1.6227],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on
# tensor([-2.6512, -8.7562,  4.0548,  ..., -4.2803, -1.5223, -4.1410],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August
# tensor([-2.7235, -8.4885,  3.2247,  ..., -3.5955, -3.5243, -3.6685],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31
# tensor([-4.5497, -9.9992,  5.4692,  ..., -4.0261, -4.7960, -2.4990],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .
# tensor([ 0.6918, -5.1235,  3.3107,  ..., -3.3402, -2.8943, -0.6562],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The
# tensor([-1.4509, -7.2669,  3.6742,  ..., -4.8623, -3.5513, -2.4180],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system
# tensor([-6.5438, -6.1203,  2.8801,  ..., -3.3480, -3.1758, -5.5536],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved
# tensor([-3.7378, -8.3197,  1.4951,  ..., -2.0140, -3.7844, -2.1646],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across
# tensor([-1.0371, -7.3438,  3.4251,  ..., -3.1545, -1.2177, -2.2576],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the
# tensor([-0.5701, -7.5991,  2.5428,  ..., -4.1567, -3.0503, -2.6137],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east
# tensor([ -3.4817, -11.7180,   3.7002,  ...,  -3.0961,  -5.3279,  -2.2951],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of
# tensor([-1.9578, -7.9873,  4.2407,  ..., -3.4616,  0.2086, -3.2557],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the
# tensor([-0.7914, -7.3963,  3.1728,  ..., -4.1517, -3.0434, -2.1929],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines
# tensor([ -2.8999, -11.9371,   5.0152,  ...,  -3.5636,  -4.6922,  -2.6205],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines ,
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines ,
# tensor([ 0.5593, -9.1292, 12.6066,  ..., -2.9445, -1.1250, -2.4318],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s>
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s>
# tensor([23.1064, -0.5682,  5.2182,  ...,  0.3180, -0.5076,  1.2588],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad>
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad>
# tensor([24.5543, -0.8966,  5.2844,  ..., -0.1265, -0.2876,  1.1082],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad>
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad>
# tensor([24.4588, -0.9913,  5.4639,  ..., -0.2446, -0.2223,  1.0862],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad>
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad>
# tensor([24.3100, -0.8810,  4.8671,  ..., -0.2234, -0.1366,  1.2360],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad>
# <s>  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad>
# tensor([24.0898, -0.7269,  3.9810,  ..., -0.1719, -0.0380,  1.4165],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad>
#  The  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad>
# tensor([23.3556, -1.0200,  4.8110,  ..., -0.6569, -0.2406,  0.9297],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad>
#  dog  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([23.1552, -0.9210,  4.0440,  ..., -0.6526, -0.0597,  0.8428],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([22.6358, -1.2855,  3.7126,  ..., -1.0952, -0.3505,  1.0535],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([22.3330, -1.2312,  3.3856,  ..., -1.2039, -0.6949,  1.0128],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([21.4090, -1.5025,  2.6450,  ..., -1.3507, -0.4363,  0.7569],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([20.8347, -1.8486,  2.1731,  ..., -1.6234, -0.5331,  0.8058],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([21.2192, -1.9962,  1.7062,  ..., -1.8374, -0.4489,  1.0149],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([20.4524, -1.7624,  1.5610,  ..., -1.9238, -0.2699,  0.8845],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([19.9325, -1.9775,  1.2334,  ..., -1.9965, -0.1701,  0.9263],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([19.2918, -2.5007,  0.8170,  ..., -2.2613, -0.7577,  0.2890],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([18.7596, -2.2112,  0.1336,  ..., -2.3202, -1.0423,  0.5812],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([18.1060, -2.1231, -0.0346,  ..., -2.3634, -0.7267,  0.4944],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([17.2008, -2.4996, -0.2094,  ..., -2.5455, -0.5328,  0.4594],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([16.6696, -3.0865, -0.6007,  ..., -2.5130, -0.7966,  0.4370],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([16.2354, -2.7627, -0.2314,  ..., -2.3969, -0.5810,  0.8169],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([15.7633, -2.8902, -0.1891,  ..., -2.5510, -0.2722,  0.4505],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([15.1344, -3.0945, -0.1268,  ..., -2.4488, -0.4378,  0.5407],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([14.7975, -2.3566, -0.7450,  ..., -2.5153, -0.4684,  0.7997],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([14.2055, -2.5421, -0.7973,  ..., -2.6626, -0.2428,  0.6202],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.3398, -2.4531, -0.5419,  ..., -2.5915,  0.0711,  1.1385],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.0886, -1.8809, -0.6575,  ..., -2.7130, -0.3146,  0.9519],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([12.6792, -2.1664, -0.7795,  ..., -2.5612, -0.1853,  1.0811],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([11.9915, -2.6650, -1.1227,  ..., -2.7081, -0.8168,  0.5584],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([11.2264, -2.7025, -0.7479,  ..., -2.9516, -0.9222,  0.7839],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([10.3132, -2.8417, -0.5854,  ..., -3.0107, -0.9299,  0.7915],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 9.3727, -3.3390, -0.4799,  ..., -3.1371, -0.9833,  0.8069],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 9.4273, -3.1619, -0.4075,  ..., -2.7809, -1.1713,  0.5328],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 9.8818, -2.4807, -0.6093,  ..., -2.6866, -0.9479,  0.6392],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 9.0077, -1.8435, -1.1214,  ..., -3.1990, -0.2095,  0.6399],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 8.5622, -2.2857, -0.8764,  ..., -2.8587, -0.5835,  0.7035],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 8.4752e+00, -3.4079e+00, -6.9314e-01,  ..., -3.5064e+00,
#         -1.1878e+00, -1.2141e-03], grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 7.6192, -3.6070, -1.1219,  ..., -3.9256, -0.7162, -0.0500],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 6.9710, -4.2082, -0.6097,  ..., -3.4727, -1.0125, -0.0734],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([ 5.4398, -4.1931, -0.2123,  ..., -3.6752, -1.8246, -0.1923],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D
# <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D
# tensor([-2.8735, -7.3338,  1.5734,  ..., -4.0192, -2.8315, -1.4398],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and
# tensor([-4.0980, -4.9851,  0.7170,  ..., -4.5224, -2.8253, -2.1250],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the
# tensor([-2.0094, -4.3914,  1.6475,  ..., -5.2739, -1.8125, -2.0267],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east
# tensor([-4.2749, -7.4766,  3.0685,  ..., -3.5144, -3.1637, -1.9929],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of
# tensor([-2.6451, -4.9566,  2.8182,  ..., -4.4333, -0.3235, -1.7533],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the
# tensor([-1.5165, -4.9331,  3.4321,  ..., -5.2276, -1.7790, -1.8825],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong
# tensor([-4.5612, -9.1066,  2.8898,  ..., -2.8712, -3.4475, -2.0975],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and
# tensor([-4.2283, -6.1306,  3.2774,  ..., -4.7145, -3.1262, -2.4656],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the
# tensor([-1.6429, -5.5195,  4.8449,  ..., -4.9527, -1.8406, -2.0041],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east
# tensor([-4.1271, -8.4744,  6.1319,  ..., -2.8035, -3.5096, -2.2801],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of
# tensor([-2.1492, -6.2171,  6.4139,  ..., -4.0336, -0.2833, -1.8790],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the
# tensor([-0.9813, -6.3576,  6.6145,  ..., -4.7291, -1.9037, -1.9965],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong
# tensor([-4.7347, -9.8715,  5.3295,  ..., -2.2441, -3.6849, -1.9812],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and
# tensor([-4.2959, -7.3981,  6.1441,  ..., -4.3734, -3.3683, -2.6145],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the
# tensor([-1.3355, -6.8782,  7.5075,  ..., -4.4148, -2.1113, -2.1413],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s>
# tensor([13.0030, -2.6790,  4.1362,  ..., -1.8144, -2.2800,  0.5950],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad>
# tensor([15.7817, -3.0409,  3.9467,  ..., -1.6721, -1.7966,  0.9769],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad>
# tensor([16.2881, -2.9069,  3.5300,  ..., -1.7998, -1.6562,  1.0657],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad>
# tensor([16.3126, -2.9403,  3.3526,  ..., -1.9720, -1.6226,  1.0491],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad>
# tensor([15.8538, -3.1523,  3.3753,  ..., -2.1916, -1.6903,  0.9733],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad>
# tensor([15.1692, -3.3747,  3.3604,  ..., -2.3839, -1.8149,  0.9383],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([14.6502, -3.4620,  3.2532,  ..., -2.5103, -1.8977,  0.9549],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([14.2387, -3.5059,  3.1128,  ..., -2.6212, -1.9551,  0.9531],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.9080, -3.5470,  2.9603,  ..., -2.7296, -2.0000,  0.9327],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.6726, -3.5926,  2.8150,  ..., -2.8338, -2.0344,  0.9088],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.5016, -3.6363,  2.6811,  ..., -2.9290, -2.0592,  0.8884],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.3627, -3.6585,  2.5565,  ..., -3.0131, -2.0721,  0.8789],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.2609, -3.6412,  2.4137,  ..., -3.0856, -2.0696,  0.8803],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# tensor([13.1806, -3.6030,  2.2316,  ..., -3.1465, -2.0557,  0.8811],
#        grad_fn=<SelectBackward0>)
# The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Text prompt:
#  The dog ran
# Number of tokens to generate: 100
# Generated_text:
#  The dog ran  into  a  tropical  depression  on  August  19 ,  and  the  JMA  upgraded  the  storm  to  tropical  cyclones  on  August  31 .  The  system  moved  across  the  east  of  the  Philippines , <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>  D  and  the  east  of  the  Naktong  and  the  east  of  the  Naktong  and  the <\s> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
